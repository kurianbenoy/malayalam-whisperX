# %%
import whisperx
import gc 

device = "cuda" 
audio_file = "20201113_MYY_Buddhiman.mp3"
batch_size = 16 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# 1. Transcribe with original whisper (batched)
model = whisperx.load_model("kurianbenoy/vegam-whisper-medium-ml", device, compute_type=compute_type)

audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio, batch_size=batch_size)
print(result["segments"]) # before alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model

# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code="ml", device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)

print(result["segments"]) # after alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model_a

# 3. Assign speaker labels
diarize_model = whisperx.DiarizationPipeline(use_auth_token="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", device=device)
# add min/max number of speakers if known
diarize_segments = diarize_model(audio)
# diarize_model(audio, min_speakers=min_speakers, max_speakers=max_speakers)

result = whisperx.assign_word_speakers(diarize_segments, result)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.1.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint .cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.0.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.1.0. Bad things might happen unless you revert torch to 1.x.
# Detected language: ta (0.86) in first 30s of audio...
# [{'text': 'ദൈവത്തിന് സ്തോത്രം ദൈവത്തിന് സ്തൂതി കർത്താവാന് മുഖത്വം സ്തോത്രം സ്തോത്രം സ്തോത്രം കർത്താവാ യേശക്രിസ്ത�', 'start': 0.009, 'end': 25.913}, {'text': 'അതിന് നിങ്ങൾ നിങ്ങൾത്തിനെ വിധേയരാക്കുന്നത് കൊണ്ടാണ് നന്ദി ഞാൻ പറഞ്ഞത് വധനം പറയുന്നത് സ്നേഹം കൊണ്ടാണ് നിങ�', 'start': 25.913, 'end': 54.002}, {'text': 'നിത്യജീവം പ്രാവിക്കാൻ ഇടയാകുന്നെങ്കിൽ അതൊരു ഭാഗ്യമാണ് അതാണ് വധനം തരുന്നതിൻറെ ലക്ഷ്യം നിത്യജീവൻ എവർലാസ്റ�', 'start': 54.002, 'end': 75.759}, {'text': 'പിന്നെ പിന്നെ ഓരോ നൂറ്റാണ്ടുകളിലും ദൈവമനുക്കൾ കർത്താൻറെ വേലയായി ഇതവര് ദൈവത്തിന് സ്തോദനം കോൺസ്റ്റൻഡ് റ�', 'start': 76.203, 'end': 93.063}, {'text': 'സഭയിൽ കടന്നു കൂടിയപ്പോൾ മാർട്ടൽ ലൂവർ എഴുതിച്ചു മാർട്ടൽ ലൂവർ റിഫർമേഷൻ നവികരണം കാലങ്ങൾ മുന്നോട്ടുപോയി പി�', 'start': 93.507, 'end': 110.606}, {'text': 'കത്തവൻറെ വേലക്കാരായി വന്നു ലക്ഷ്യം വന്നായിരുന്നു യേശുകൃസ്തന സാക്ഷിക്കുക എന്നുള്ളതായിരുന്നു സുവിശേഷം മാ�', 'start': 110.606, 'end': 133.046}, {'text': 'തലമുറകൾ തലമുറകൾ കഴിഞ്ഞു കഴിഞ്ഞു പോകുന്നു നമും ഇന്നു ജീവിക്കുന്നു നാളെ നാൻ മൺമറയാം ദൈവത്തിന് സ്തോദ്രം എന�', 'start': 133.046, 'end': 155.367}, {'text': 'നിത്യമരണത്തിലേക്ക് നിത്യയാധനയിലേക്ക് പോകുന്നു ഒന്നികിൽ നിത്യജീവൻ എന്ന സ്വർഗം അല്ലെങ്കിൽ നിത്യനാശം എന്ന �', 'start': 155.367, 'end': 180.213}, {'text': 'ദുരുപദേശങ്ങൾ മാറി പോകും ദുരാഗ്രഹങ്ങൾ മാറി പോകും നമ്മുടെ ജടിക സ്വഭാവങ്ങൾ എല്ലാം മാറി മാറി പോകും നമുക്ക് ദൈവ', 'start': 180.555, 'end': 207.005}, {'text': 'വധനം എന്ന മായവില്ലാത്ത പാൽ കുടിപ്പാൻ വാഞ്ഞിപ്പീൻ എന്തിന് രക്ഷക്കായി ഉളർവാൻ രക്ഷക്കായി ഉളർവാൻ വധനം എന്ന മായവ�', 'start': 207.005, 'end': 231.118}, {'text': 'ഇതെല്ലാം കലർത്തി പാല് കൊടുത്തിട്ടുണ്ട് മായം കലർന്ന പാല് അത് ഒരിക്കലും നമസ്വീകരിച്ചുകൂടാ എപ്പോൾ ഓർത്തുക�', 'start': 231.118, 'end': 260.316}, {'text': 'ഒരേ ഒരു ലീഡർ മാത്രമേ ഉള്ളൂ ക്രിസ്തു മാത്രം ഒരേ ഒരു രക്ഷകൻ മാത്രമേ ഉള്ളൂ ക്രിസ്തു മാത്രം രക്ഷകൻനാരില്ല രക്�', 'start': 260.316, 'end': 280.111}, {'text': 'ഈ സുവിശേഷം അത് പ്രഖ്യാപിക്കുവനാണ് നമ്മെ ഈ ഭൂമിയിൽ നിയവിച്ച് ആക്കിയിരിക്കുന്നത് ഈ സുവിശേഷം വിശ്വസിക്കുന്നവ', 'start': 280.111, 'end': 301.305}, {'text': 'സ്തുതി സ്തുതി എന്ന് പറയുന്നതോ പ്രീസ് തലോടെന്ന് പറയുന്നതോ ഹാലോരിയ എന്ന് പറയുന്നതോ അതെല്ലാം അധരങ്ങളിൽ മാത�', 'start': 301.305, 'end': 331.032}, {'text': 'കുർബാനിയുടെ അവസാനത്തെ ഗീതത്തിൽ തുടങ്ങുമ്പോൾ പറയുന്നത് മേൽപ്പെട്ടക്കാർ പട്ടക്കാരുടെ ശിമ്മാശന്മാർ ഏർപ�', 'start': 331.032, 'end': 355.828}, {'text': 'സഭവിടം മക്കളേ സ്തുതി അഭ്യസ്പിക്കാനാണ് അന്യവരതം നിരന്തരമായ സ്തുതി ഇടപ്പെടാത്ത സ്തുതി അർപ്പിക്കുക എന്നുള്ള �', 'start': 355.828, 'end': 374.872}, {'text': 'നാം ധരിക്കേണ്ട ഒരു മേലാടിയാണ് സ്തുതി യശയപ്രഭാദകൻ പറയും സ്തുതി എന്ന മേലാടായെന്ന് നാം ധരിക്കേണ്ടതായ ഒരു പട്ട�', 'start': 374.872, 'end': 395.503}, {'text': 'കർത്തായുകാരെ ഭൂമിയ തിങ്കൽ അണിയേച്ചാരി വരനിശം തന്നുടെ സഭയെ എവിടെ അനവരതം ചെയ്തേറ്റിവസിക്കും സ്തുതികൾ അല്ലതാ�', 'start': 395.503, 'end': 422.807}, {'text': 'കർത്താവായി യേശുവിന്റെ രണ്ടാമത്തെ ഒരിൽ കാഹ്ലനാദം കേട്ടുമ്പോൾ നമുക്ക് പറന്നു വിരാൻ പറ്റുമുകയുള്ളൂ യേശുക�', 'start': 422.807, 'end': 441.92}, {'text': 'എഴുന്നേറ്റ് ബുദ്ധിയുള്ള കന്നീയമാരെ പോലെ വെള്ക്കുകളയിച്ച് പറന്നു വീരണമെങ്കിൽ ഈ സ്തുതി എന്ന മേലാടെ എന്ന�', 'start': 442.568, 'end': 463.387}, {'text': 'നമുക്ക് കർത്താവിന്റെ വേല വിശ്വസതയോട് നിമർത്തിക്കാൻ സാധിക്കുകയുള്ളൂ നമ്മുടെ ചിന്താവശീയം നിങ്ങൾക്ക്  ഓർമ', 'start': 463.387, 'end': 484.462}, {'text': 'തക്കസമയത്ത് ആഹാരവീദം കൊടുക്കേണ്ടതിന് യജമാനൻ തൻറെ വേലക്കാരുടെ മേൽ ആക്കിവയ്ക്കുന്ന വിശ്വസ്തൻ ബുദ്ധിമാനു�', 'start': 484.462, 'end': 502.978}, {'text': 'ബുദ്ധിയുള്ള കന്നികമാർ പത്തു കന്നികമാരിൽ ലഞ്ചു പേർ ബുദ്ധിയില്ലാത്ത ലഞ്ചു പേർ ബുദ്ധിയുള്ളവരുമായിരുന്നു ബ', 'start': 502.978, 'end': 529.753}, {'text': 'പത്തെണ്ടവധ്യായി മൂന്നാം വാക്കി നോക്ക് വായിക്കാം ധാനിയിൽ പത്തെണ്ടിന്റെ മൂന്ന്', 'start': 529.753, 'end': 546.015}, {'text': 'ബുദ്ധിമാൻമാർ ആകാശമുണ്ഡലത്തിൻറെ പ്രഭവപോലെയും പലരെയും നീതീയിലേക്ക് തിരിക്കുന്നവർ നക്ഷത്രങ്ങളെ പോലെയും �', 'start': 546.101, 'end': 565.435}, {'text': 'ബുദ്ധിവന്മാർ ആകാശവണ്ഡലത്തിൻറെ പ്രഭവപോലെയും പലരെയും നീതിയിലേക്ക് തിരിക്കുന്നവർ നഷ്ടത്രങ്ങളെ പോലെയും എന�', 'start': 565.435, 'end': 589.838}, {'text': 'അവരുടെ പ്രൊഫഷൻ അവരുടെ ജോലി അനേകരെ നീതിയിലേക്ക് തിരിക്കുക എന്നുള്ളതാണ് അനേകർക്ക് ദൈവന് ...
# Ignored unknown kwarg option normalize
# Ignored unknown kwarg option normalize
# Ignored unknown kwarg option normalize
# Ignored unknown kwarg option normalize
# Some weights of the model checkpoint at gvs/wav2vec2-large-xlsr-malayalam were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at gvs/wav2vec2-large-xlsr-malayalam and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [{'start': 0.009, 'end': 7.996, 'text': 'ദൈവത്തിന് സ്തോത്രം ദൈവത്തിന് സ്തൂതി കർത്താവാന് മുഖത്വം സ്തോത്രം സ്തോത്രം സ്തോത്രം കർത്താവാ യേശക്രിസ്ത�', 'words': [{'word': 'ദൈവത്തിന്', 'start': 0.009, 'end': 1.05, 'score': 0.189}, {'word': 'സ്തോത്രം', 'start': 1.11, 'end': 1.631, 'score': 0.356}, {'word': 'ദൈവത്തിന്', 'start': 2.071, 'end': 2.471, 'score': 0.335}, {'word': 'സ്തൂതി', 'start': 2.531, 'end': 3.012, 'score': 0.264}, {'word': 'കർത്താവാന്', 'start': 3.372, 'end': 3.893, 'score': 0.345}, {'word': 'മുഖത്വം', 'start': 3.913, 'end': 4.373, 'score': 0.291}, {'word': 'സ്തോത്രം', 'start': 4.753, 'end': 5.294, 'score': 0.378}, {'word': 'സ്തോത്രം', 'start': 5.394, 'end': 5.874, 'score': 0.401}, {'word': 'സ്തോത്രം', 'start': 5.955, 'end': 6.435, 'score': 0.422}, {'word': 'കർത്താവാ', 'start': 6.915, 'end': 7.416, 'score': 0.151}, {'word': 'യേശക്രിസ്ത�', 'start': 7.456, 'end': 7.996, 'score': 0.447}]}, {'start': 25.913, 'end': 33.335, 'text': 'അതിന് നിങ്ങൾ നിങ്ങൾത്തിനെ വിധേയരാക്കുന്നത് കൊണ്ടാണ് നന്ദി ഞാൻ പറഞ്ഞത് വധനം പറയുന്നത് സ്നേഹം കൊണ്ടാണ് നിങ�', 'words': [{'word': 'അതിന്', 'start': 25.913, 'end': 26.313, 'score': 0.266}, {'word': 'നിങ്ങൾ', 'start': 26.333, 'end': 26.753, 'score': 0.379}, {'word': 'നിങ്ങൾത്തിനെ', 'start': 27.373, 'end': 27.834, 'score': 0.529}, {'word': 'വിധേയരാക്കുന്നത്', 'start': 27.854, 'end': 28.634, 'score': 0.452}, {'word': 'കൊണ്ടാണ്', 'start': 28.654, 'end': 29.074, 'score': 0.291}, {'word': 'നന്ദി', 'start': 29.134, 'end': 29.534, 'score': 0.423}, {'word': 'ഞാൻ', 'start': 29.894, 'end': 30.034, 'score': 0.1}, {'word': 'പറഞ്ഞത്', 'start': 30.074, 'end': 30.454, 'score': 0.451}, {'word': 'വധനം', 'start': 30.915, 'end': 31.195, 'score': 0.298}, {'word': 'പറയുന്നത്', 'start': 31.235, 'end': 31.875, 'score': 0.362}, {'word': 'സ്നേഹം', 'start': 32.015, 'end': 32.395, 'score': 0.258}, {'word': 'കൊണ്ടാണ്', 'start': 32.415, 'end': 32.815, 'score': 0.535}, {'word': 'നിങ�', 'start': 33.255, 'end': 33.335, 'score': 0.427}]}, {'start': 54.002, 'end': 62.349, 'text': 'നിത്യജീവം പ്രാവിക്കാൻ ഇടയാകുന്നെങ്കിൽ അതൊരു ഭാഗ്യമാണ് അതാണ് വധനം തരുന്നതിൻറെ ലക്ഷ്യം നിത്യജീവൻ എവർലാസ്റ�', 'words': [{'word': 'നിത്യജീവം', 'start': 54.002, 'end': 54.522, 'score': 0.233}, {'word': 'പ്രാവിക്കാൻ', 'start': 54.562, 'end': 55.203, 'score': 0.493}, {'word': 'ഇടയാകുന്നെങ്കിൽ', 'start': 55.283, 'end': 56.104, 'score': 0.451}, {'word': 'അതൊരു', 'start': 56.144, 'end': 56.364, 'score': 0.563}, {'word': 'ഭാഗ്യമാണ്', 'start': 56.424, 'end': 57.064, 'score': 0.342}, {'word': 'അതാണ്', 'start': 57.565, 'end': 58.065, 'score': 0.245}, {'word': 'വധനം', 'start': 58.145, 'end': 58.506, 'score': 0.126}, {'word': 'തരുന്നതിൻറെ', 'start': 59.026, 'end': 59.566, 'score': 0.383}, {'word': 'ലക്ഷ്യം', 'start': 59.626, 'end': 60.107, 'score': 0.358}, {'word': 'നിത്യജീവൻ', 'start': 60.527, 'end': 61.548, 'score': 0.206}, {'word': 'എവർലാസ്റ�', 'start': 61.908, 'end': 62.349, 'score': 0.327}]}, {'start': 76.203, 'end': 81.99, 'text': 'പിന്നെ പിന്നെ ഓരോ നൂറ്റാണ്ടുകളിലും ദൈവമനുക്കൾ കർത്താൻറെ വേലയായി ഇതവര് ദൈവത്തിന് സ്തോദനം കോൺസ്റ്റൻഡ് റ�', 'words': [{'word': 'പിന്നെ', 'start': 76.203, 'end': 76.483, 'score': 0.49}, {'word': 'പിന്നെ', 'start': 76.503, 'end': 76.704, 'score': 0.522}, {'word': 'ഓരോ', 'start': 76.764, 'end': 77.004, 'score': 0.197}, {'word': 'നൂറ്റാണ്ടുകളിലും', 'start': 77.044, 'end': 77.785, 'score': 0.394}, {'word': 'ദൈവമനുക്കൾ', 'start': 78.225, 'end': 78.646, 'score': 0.21}, {'word': 'കർത്താൻറെ', 'start': 78.726, 'end': 79.066, 'score': 0.395}, {'word': 'വേലയായി', 'start': 79.086, 'end': 79.347, 'score': 0.274}, {'word': 'ഇതവര്', 'start': 79.387, 'end': 79.687, 'score': 0.206}, {'word': 'ദൈവത്തിന്', 'start': 80.208, 'end': 80.568, 'score': 0.611}, {'word': 'സ്തോദനം', 'start': 80.608, 'end': 81.049, 'score': 0.296}, {'word': 'കോൺസ്റ്റൻഡ്', 'start': 81.509, 'end': 81.95, 'score': 0.166}, {'word': 'റ�', 'start': 81.97, 'end': 81.99, 'score': 0.365}]}, {'start': 93.507, 'end': 100.435, 'text': 'സഭയിൽ കടന്നു കൂടിയപ്പോൾ മാർട്ടൽ ലൂവർ എഴുതിച്ചു മാർട്ടൽ ലൂവർ റിഫർമ ...
#                                segment  label     speaker        start  \
# 0    [ 00:00:00.449 -->  00:00:22.011]      1  SPEAKER_01     0.449915
# 1    [ 00:00:22.130 -->  00:00:23.098]      1  SPEAKER_01    22.130730
# 2    [ 00:00:23.505 -->  00:00:25.458]      1  SPEAKER_01    23.505942
# 3    [ 00:00:25.984 -->  00:00:26.833]      1  SPEAKER_01    25.984720
# 4    [ 00:00:27.275 -->  00:01:03.302]      1  SPEAKER_01    27.275042
# ..                                 ...    ...         ...          ...
# 189  [ 00:22:11.842 -->  00:22:16.069]      1  SPEAKER_01  1331.842105
# 190  [ 00:22:16.375 -->  00:22:25.611]      0  SPEAKER_00  1336.375212
# 191  [ 00:22:25.882 -->  00:22:42.045]      1  SPEAKER_01  1345.882852
# 192  [ 00:22:42.283 -->  00:24:47.156]      1  SPEAKER_01  1362.283531
# 193  [ 00:24:47.190 -->  00:26:46.001]      1  SPEAKER_01  1487.190153
#
#              end  intersection        union
# 0      22.011885  -1576.027115  1598.391085
# 1      23.098472  -1574.940528  1576.710270
# 2      25.458404  -1572.580596  1575.335058
# 3      26.833616  -1571.205384  1572.856280
# 4      63.302207  -1534.736793  1571.565958
# ..           ...           ...          ...
# 189  1336.069610   -261.969390   266.998895
# 190  1345.611205   -252.427795   262.465788
# 191  1362.045840   -235.993160   252.958148
# 192  1487.156197   -110.882803   236.557469
# 193  1606.001698      0.802000   118.811545
#
# [194 rows x 7 columns]
# [{'start': 0.009, 'end': 7.996, 'text': 'ദൈവത്തിന് സ്തോത്രം ദൈവത്തിന് സ്തൂതി കർത്താവാന് മുഖത്വം സ്തോത്രം സ്തോത്രം സ്തോത്രം കർത്താവാ യേശക്രിസ്ത�', 'words': [{'word': 'ദൈവത്തിന്', 'start': 0.009, 'end': 1.05, 'score': 0.189, 'speaker': 'SPEAKER_01'}, {'word': 'സ്തോത്രം', 'start': 1.11, 'end': 1.631, 'score': 0.356, 'speaker': 'SPEAKER_01'}, {'word': 'ദൈവത്തിന്', 'start': 2.071, 'end': 2.471, 'score': 0.335, 'speaker': 'SPEAKER_01'}, {'word': 'സ്തൂതി', 'start': 2.531, 'end': 3.012, 'score': 0.264, 'speaker': 'SPEAKER_01'}, {'word': 'കർത്താവാന്', 'start': 3.372, 'end': 3.893, 'score': 0.345, 'speaker': 'SPEAKER_01'}, {'word': 'മുഖത്വം', 'start': 3.913, 'end': 4.373, 'score': 0.291, 'speaker': 'SPEAKER_01'}, {'word': 'സ്തോത്രം', 'start': 4.753, 'end': 5.294, 'score': 0.378, 'speaker': 'SPEAKER_01'}, {'word': 'സ്തോത്രം', 'start': 5.394, 'end': 5.874, 'score': 0.401, 'speaker': 'SPEAKER_01'}, {'word': 'സ്തോത്രം', 'start': 5.955, 'end': 6.435, 'score': 0.422, 'speaker': 'SPEAKER_01'}, {'word': 'കർത്താവാ', 'start': 6.915, 'end': 7.416, 'score': 0.151, 'speaker': 'SPEAKER_01'}, {'word': 'യേശക്രിസ്ത�', 'start': 7.456, 'end': 7.996, 'score': 0.447, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 25.913, 'end': 33.335, 'text': 'അതിന് നിങ്ങൾ നിങ്ങൾത്തിനെ വിധേയരാക്കുന്നത് കൊണ്ടാണ് നന്ദി ഞാൻ പറഞ്ഞത് വധനം പറയുന്നത് സ്നേഹം കൊണ്ടാണ് നിങ�', 'words': [{'word': 'അതിന്', 'start': 25.913, 'end': 26.313, 'score': 0.266, 'speaker': 'SPEAKER_01'}, {'word': 'നിങ്ങൾ', 'start': 26.333, 'end': 26.753, 'score': 0.379, 'speaker': 'SPEAKER_01'}, {'word': 'നിങ്ങൾത്തിനെ', 'start': 27.373, 'end': 27.834, 'score': 0.529, 'speaker': 'SPEAKER_01'}, {'word': 'വിധേയരാക്കുന്നത്', 'start': 27.854, 'end': 28.634, 'score': 0.452, 'speaker': 'SPEAKER_01'}, {'word': 'കൊണ്ടാണ്', 'start': 28.654, 'end': 29.074, 'score': 0.291, 'speaker': 'SPEAKER_01'}, {'word': 'നന്ദി', 'start': 29.134, 'end': 29.534, 'score': 0.423, 'speaker': 'SPEAKER_01'}, {'word': 'ഞാൻ', 'start': 29.894, 'end': 30.034, 'score': 0.1, 'speaker': 'SPEAKER_01'}, {'word': 'പറഞ്ഞത്', 'start': 30.074, 'end': 30.454, 'score': 0.451, 'speaker': 'SPEAKER_01'}, {'word': 'വധനം', 'start': 30.915, 'end': 31.195, 'score': 0.298, 'speaker': 'SPEAKER_01'}, {'word': 'പറയുന്നത്', 'start': 31.235, 'end': 31.875, 'score': 0.362, 'speaker': 'SPEAKER_01'}, {'word': 'സ്നേഹം', 'start': 32.015, 'end': 32.395, 'score': 0.258, 'speaker': 'SPEAKER_01'}, {'word': 'കൊണ്ടാണ്', 'start': 32.415, 'end': 32.815, 'score': 0.535, 'speaker': 'SPEAKER_01'}, {'word': 'നിങ�', 'start': 33.255, 'end': 33.335, 'score': 0.427, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 54.002, 'end': 62.349, 'text': 'നിത്യജീവം പ്രാവിക്കാൻ ഇടയാകുന്നെങ്കിൽ അതൊരു ഭാഗ്യമാണ് അതാണ് വധനം തരുന്നതിൻറെ ലക്ഷ്യം നിത്യജീവൻ എവർലാസ്റ�', 'words': [{'word': 'നിത്യജീവം', 'start': 54.002, 'end': 54.522, 'score': 0.233, 'speaker': 'SPEAKER_01'}, {'word': 'പ്രാവിക്കാൻ', 'start': 54.562, 'end': 55.203, 'score': 0.493, 'speaker': 'SPEAKER_01'}, {'word': 'ഇടയാകുന്നെങ്കിൽ', 'start': 55.283, 'end': 56.104, 'score': 0.451, 'speaker': 'SPEAKER_01'}, {'word': 'അതൊരു', 'start': 56.144, 'end': 56.364, 'score': 0.563, 'speaker': 'SPEAKER_01'}, {'word': 'ഭാഗ്യമാണ്', 'start': 56.424, 'end': 57.064, 'score': 0.342, 'speaker': 'SPEAKER_01'}, {'word': 'അതാണ്', 'start': 57.565, 'end': 58.065, 'score': 0.245, 'speaker': 'SPEAKER_01'}, {'word': 'വധനം', 'start': 58.145, 'end': 58.506, 'score': 0.126, 'speaker': 'SPEAKER_01'}, {'word': 'തരുന്നതിൻറെ', 'start': 59.026, 'end': 59.566, 'score': 0.383, 'speaker': 'SPEAKER_01'}, {'word': 'ലക്ഷ്യം', 'start': 59.626, 'end': 60.107, 'score': 0.358, 'speaker': 'SPEAKER_01'}, {'word': 'നിത്യജീവൻ', 'start': 60.527, 'end': 61.548, 'score': 0.206, 'speaker': 'SPEAKER_01'}, {'word': 'എവർലാസ്റ�', 'start': 61.908, 'end': 62.349, 'score': 0.327, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 76.203, 'end': 81.99, 'text': 'പിന്നെ പിന്നെ ഓരോ നൂറ്റാണ്ടുകളിലും ദൈവമനുക്കൾ കർത്താൻറെ വേലയായി ഇതവര് ദൈവത്തിന് സ്തോദനം കോൺസ്റ്റൻഡ് റ�',  ...

# %%
import whisperx
import gc 

device = "cuda" 
audio_file = "anil.wav"
batch_size = 16 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# 1. Transcribe with original whisper (batched)
model = whisperx.load_model("kurianbenoy/vegam-whisper-medium-ml", device, compute_type=compute_type)

audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio, batch_size=batch_size)
print(result["segments"]) # before alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model

# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code="ml", device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)

print(result["segments"]) # after alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model_a

# 3. Assign speaker labels
diarize_model = whisperx.DiarizationPipeline(use_auth_token="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", device=device)
# add min/max number of speakers if known
diarize_segments = diarize_model(audio)
# diarize_model(audio, min_speakers=min_speakers, max_speakers=max_speakers)

result = whisperx.assign_word_speakers(diarize_segments, result)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.1.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint .cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.0.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.1.0. Bad things might happen unless you revert torch to 1.x.
# Warning: audio is shorter than 30s, language detection may be inaccurate.
# Detected language: ta (0.52) in first 30s of audio...
# [{'text': 'അവയിലൊന്ന് മരണാന്തരം പ്രസിദ്ധീകരിച്ച ഡണ്ണിന്റെ സമഹാരത്തിൽ ഉൾപ്പെടുത്തിയിരുന്നു', 'start': 0.145, 'end': 6.425}]
# Ignored unknown kwarg option normalize
# Ignored unknown kwarg option normalize
# Ignored unknown kwarg option normalize
# Ignored unknown kwarg option normalize
# Some weights of the model checkpoint at gvs/wav2vec2-large-xlsr-malayalam were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at gvs/wav2vec2-large-xlsr-malayalam and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [{'start': 0.165, 'end': 6.325, 'text': 'അവയിലൊന്ന് മരണാന്തരം പ്രസിദ്ധീകരിച്ച ഡണ്ണിന്റെ സമഹാരത്തിൽ ഉൾപ്പെടുത്തിയിരുന്നു', 'words': [{'word': 'അവയിലൊന്ന്', 'start': 0.165, 'end': 0.827, 'score': 0.362}, {'word': 'മരണാന്തരം', 'start': 1.168, 'end': 1.991, 'score': 0.275}, {'word': 'പ്രസിദ്ധീകരിച്ച', 'start': 2.131, 'end': 2.974, 'score': 0.56}, {'word': 'ഡണ്ണിന്റെ', 'start': 3.395, 'end': 3.997, 'score': 0.47}, {'word': 'സമഹാരത്തിൽ', 'start': 4.338, 'end': 5.281, 'score': 0.379}, {'word': 'ഉൾപ്പെടുത്തിയിരുന്നു', 'start': 5.562, 'end': 6.325, 'score': 0.643}]}]
#                              segment  label     speaker     start       end  \
# 0  [ 00:00:00.008 -->  00:00:06.443]      0  SPEAKER_00  0.008489  6.443124
#
#    intersection     union
# 0         0.763  6.434635
# [{'start': 0.165, 'end': 6.325, 'text': 'അവയിലൊന്ന് മരണാന്തരം പ്രസിദ്ധീകരിച്ച ഡണ്ണിന്റെ സമഹാരത്തിൽ ഉൾപ്പെടുത്തിയിരുന്നു', 'words': [{'word': 'അവയിലൊന്ന്', 'start': 0.165, 'end': 0.827, 'score': 0.362, 'speaker': 'SPEAKER_00'}, {'word': 'മരണാന്തരം', 'start': 1.168, 'end': 1.991, 'score': 0.275, 'speaker': 'SPEAKER_00'}, {'word': 'പ്രസിദ്ധീകരിച്ച', 'start': 2.131, 'end': 2.974, 'score': 0.56, 'speaker': 'SPEAKER_00'}, {'word': 'ഡണ്ണിന്റെ', 'start': 3.395, 'end': 3.997, 'score': 0.47, 'speaker': 'SPEAKER_00'}, {'word': 'സമഹാരത്തിൽ', 'start': 4.338, 'end': 5.281, 'score': 0.379, 'speaker': 'SPEAKER_00'}, {'word': 'ഉൾപ്പെടുത്തിയിരുന്നു', 'start': 5.562, 'end': 6.325, 'score': 0.643, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_00'}]

# %%
1 + 1
# Out:
# 2
